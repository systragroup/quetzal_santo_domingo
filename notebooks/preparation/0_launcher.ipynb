# %% [markdown]
# # roads

# %%
# %run 10_osmnx.ipynb
# Out:
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 32/32 [00:54<00:00,  1.69s/it]

# %%
# %run 11_add_road.ipynb
# Out:
# can not add prefixes on table:  links
# can not add prefixes on table:  footpaths
# direct: 50632it [00:13, 3738.72it/s]
# reversed: 50632it [00:13, 3831.45it/s]
# 50588it [00:12, 3940.80it/s]
# direct: 50588it [00:13, 3821.18it/s]
# reversed: 50588it [00:13, 3767.72it/s]
# 50586it [00:13, 3622.24it/s]
# 50586it [00:03, 13039.66it/s]
# ...
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:06<00:00,  4.00it/s]

# %% [markdown]
# # GIS input

# %%
# %run 21_routes_from_gis.ipynb
# %run 61_networkcaster_gis.ipynb
# Out:
# can not add prefixes on table:  footpaths
# ...
# zones: 100%|██████████| 27/27 [00:30<00:00,  1.15s/it]
# 0 223
# 1 12
# 2 0
# 3 0
# 4 0
# dropped broken sequences: []
# 50586it [00:05, 9423.72it/s]
# 50586it [00:31, 1587.54it/s]
# ...
# CP_C2_2: 100%|██████████| 416/416 [03:39<00:00,  1.90it/s]
# No path between osm_node_7745055268 and osm_node_7847559599.
# No path between osm_node_3942489959 and osm_node_1864844289.
# No path between osm_node_7272578056 and osm_node_7847559599.
# No path between osm_node_3942489969 and osm_node_2445861066.
# jsons: 100%|██████████| 3/3 [00:00<00:00,  9.28it/s]
# Deprecated: replaced by analysis_lines

# %% [markdown]
# # GTFS input
# if the GTFS changed

# %%
# %run 22_routes_from_gtfs.ipynb
# %run 62_networkcaster_gtfs.ipynb
# Out:
# {'m2_este', 'monumental', 'sitp_tiradentes', 'sitp_sabana_larga', 'herrera', 'tram_este', 'tele_norte', 'tele_oeste', 'luperon', 'quentin', 'sitp_duarte', 'victoria', 'm2_completo', 'pantoja', 'm2', 'sitp_defillo', 'intrant', 'sitp_venezuela', 'm3', 'Tele Oeste LA', 'Tele Oeste SDO', 'sitp_churchill', 'sitp_josefa', 'sitp_lincoln', 'm1', 'sitp_marzo', 'Tramo Alcarrizos L2', 'm2_oeste', 'tram_oeste', 'ecologico', 'sitp_cdg_oeste', '27_febrero', 'sanfelipe', 'mella', 'sitp_cdg_este', '27_febrero_oeste', 'tele_alcarrizos', 'sitp_nunez', 'tramo SDO L2', 'independencia', 'sitp_prolongacion_27', 'tele_este', 'sitp_ortega'}
# stop_times ['stop_id', 'trip_id'] converted to string
# trips ['route_id', 'trip_id'] converted to string
# routes ['route_id'] converted to string
# stops ['stop_id'] converted to string
# ...
# zones: 100%|██████████| 27/27 [00:12<00:00,  2.10it/s]
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# # zones

# %%
# %run 51_initialization.ipynb
# Out:
# ...
# to_hdf(overwriting): 100%|██████████| 9/9 [00:00<00:00, 19.30it/s]

# %% [markdown]
# # Merge and build scenarios
# if the parameter file changed

# %%
# %run 63_merge_after.ipynb
# %run 80_scenarios.ipynb
# Out:
# ...
# nodes: 100%|██████████| 3/3 [00:00<00:00,  3.58it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\qchasserieau\quetzal_quartz\quetzal_santo_domingo\notebooks\preparation\63_merge_after.ipynb in <module>
# ----> 1 merged.integrity_fix_collision()
#
# c:\Users\qchasserieau\quetzal_quartz\quetzal_santo_domingo\notebooks\preparation\../../../quetzal\quetzal\model\integritymodel.py in integrity_fix_collision(self, prefixes)
#     106         """
#     107         try:
# --> 108             self.integrity_test_collision()
#     109         except AssertionError:
#     110             if len(set(self.links.index)) != len(self.links):
#
# c:\Users\qchasserieau\quetzal_quartz\quetzal_santo_domingo\notebooks\preparation\../../../quetzal\quetzal\model\integritymodel.py in integrity_test_collision(self, sets)
#      71             * requires: links, nodes, zones
# ...

# %%
# %run 52_walkmodel.ipynb
# Out:
# ...
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 34/34 [01:11<00:00,  2.09s/it]
# could not save geometry from table fare_rules
# could not save geometry from table fare_attributes
# could not save geometry from table mode_nests
# could not save geometry from table logit_scales
# could not save geometry from table utility_values
