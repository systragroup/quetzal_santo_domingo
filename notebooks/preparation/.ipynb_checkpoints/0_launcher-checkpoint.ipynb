# %% [markdown]
# # roads

# %%
# %run 10_osmnx.ipynb
# Out:
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 32/32 [00:54<00:00,  1.69s/it]

# %%
# %run 11_add_road.ipynb
# Out:
# can not add prefixes on table:  links
# can not add prefixes on table:  footpaths
# direct: 50632it [00:13, 3738.72it/s]
# reversed: 50632it [00:13, 3831.45it/s]
# 50588it [00:12, 3940.80it/s]
# direct: 50588it [00:13, 3821.18it/s]
# reversed: 50588it [00:13, 3767.72it/s]
# 50586it [00:13, 3622.24it/s]
# 50586it [00:03, 13039.66it/s]
# Reprojecting model from epsg 4326 to epsg 32619: 100%|█████████████████████████████████| 34/34 [00:16<00:00,  2.09it/s]
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:06<00:00,  4.00it/s]

# %% [markdown]
# # GIS input

# %%
# %run 21_routes_from_gis.ipynb
# %run 61_networkcaster_gis.ipynb
# Out:
# Reprojecting model from epsg 4326 to epsg 32619:  25%|████████▌                         | 8/32 [00:00<00:00, 63.97it/s]
# can not add prefixes on table:  footpaths
# Reprojecting model from epsg 4326 to epsg 32619: 100%|█████████████████████████████████| 32/32 [00:02<00:00, 13.06it/s]
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 28.03it/s]
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 31.93it/s]
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:06<00:00,  4.04it/s]
# 0 220
# 1 14
# 2 2
# 3 0
# 4 0
# dropped broken sequences: []
# 50586it [00:03, 14379.52it/s]
# 50586it [00:14, 3444.02it/s]
# nearest_link: 100%|██████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 117586.98it/s]
# CP_C34_1: 100%|██████████████████████████████████████████████████████████████████████| 416/416 [02:01<00:00,  3.43it/s]
# No path between osm_node_3942489959 and osm_node_3301978909.
# No path between osm_node_3942489959 and osm_node_3301978909.
# No path between osm_node_3942489969 and osm_node_3944381822.
# jsons: 100%|█████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 10.17it/s]
# Deprecated: replaced by analysis_lines

# %% [markdown]
# # GTFS input
# if the GTFS changed

# %%
# %run 22_routes_from_gtfs.ipynb
# %run 62_networkcaster_gtfs.ipynb
# Out:
# {'m2_oeste', 'tele_este', 'sitp_lincoln', 'Tele Oeste LA', 'sitp_tiradentes', 'sitp_ortega', 'm2_este', 'tramo SDO L2', 'sitp_josefa', 'm2', 'monumental', 'sitp_churchill', 'quentin', 'herrera', 'independencia', 'tele_alcarrizos', 'sanfelipe', '27_febrero', 'sitp_sabana_larga', '27_febrero_oeste', 'sitp_marzo', 'victoria', 'Tramo Alcarrizos L2', 'ecologico', 'tele_norte', 'm3', 'm2_completo', 'pantoja', 'sitp_nunez', 'm1', 'tram_oeste', 'intrant', 'sitp_cdg_oeste', 'tram_este', 'mella', 'tele_oeste', 'sitp_defillo', 'Tele Oeste SDO', 'sitp_cdg_este', 'luperon', 'sitp_prolongacion_27', 'sitp_duarte', 'sitp_venezuela'}
# stop_times ['stop_id', 'trip_id'] converted to string
# trips ['route_id', 'trip_id'] converted to string
# routes ['route_id'] converted to string
# stops ['stop_id'] converted to string
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 47.82it/s]
# to_hdf(overwriting):   0%|                                                                      | 0/32 [00:00<?, ?it/s]
# could not save geometry from table fare_rules
# could not save geometry from table fare_attributes
# could not save geometry from table mode_nests
# could not save geometry from table logit_scales
# could not save geometry from table utility_values
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 76.35it/s]
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 66.80it/s]
# zones: 100%|██████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 122.69it/s]
# Reprojecting model from epsg 4326 to epsg 32619: 100%|█████████████████████████████████| 33/33 [00:01<00:00, 26.85it/s]
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:07<00:00,  3.70it/s]
# can not add prefixes on table:  footpaths
# dropped broken sequences: []
# 50586it [00:03, 15590.36it/s]
# 50586it [00:13, 3730.79it/s]
# nearest_link: 100%|████████████████████████████████████████████████████████████| 2810/2810 [00:00<00:00, 133828.34it/s]
# nearest_link: 100%|████████████████████████████████████████████████████████████| 5620/5620 [00:00<00:00, 124902.57it/s]
# sitp_lincoln_2: 100%|██████████████████████████████████████████████████████████████████| 32/32 [00:17<00:00,  1.82it/s]
# jsons: 100%|█████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 52.63it/s]
# Deprecated: replaced by analysis_lines

# %% [markdown]
# # zones

# %%
# %run 51_initialization.ipynb
# Out:
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 65.18it/s]
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 38.67it/s]
# could not save geometry from table fare_rules
# could not save geometry from table fare_attributes
# could not save geometry from table mode_nests
# could not save geometry from table logit_scales
# could not save geometry from table utility_values

# %% [markdown]
# # Merge and build scenarios
# if the parameter file changed

# %%
# %run 63_merge_after.ipynb
# %run 80_scenarios.ipynb
# Out:
# C:\Users\qchasserieau\AppData\Roaming\Python\Python37\site-packages\pyproj\crs\crs.py:280: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(projparams)
# nodes: 100%|█████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 37.70it/s]
# SQLalchemy is not installed. No support for SQL output.
# nodes: 100%|█████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.63it/s]
#   0%|                                                                                           | 0/27 [00:00<?, ?it/s]
# can not add prefixes on table:  footpaths
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 40.76it/s]
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 30.52it/s]
# links: 100%|██████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 743.37it/s]
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
# routes that belong to gtfs and not to parameters (will not be used):
# {'tramo SDO L2', 'Tramo Alcarrizos L2', 'sitp_tiradentes', 'quentin', 'Tele Oeste LA', 'intrant', 'Tele Oeste SDO'}
# {'sanfelipe', 'sitp_nunez', 'AB_A20A_2', 'AB_A20B_2', 'AB_A20A_1', 'sitp_ortega', 'AB_A20B_1', '27_febrero', 'AB_A-B_1', 'AB_A31_1', 'independencia', 'sitp_josefa', 'AB_A31_2', 'sitp_prolongacion_27', 'AB_A11_1', 'AB_A69_2', 'sitp_venezuela', 'sitp_sabana_larga', 'sitp_churchill', 'AB_A11_2', 'victoria', 'AB_A69_1', 'AB_A-B_2', 'sitp_lincoln', 'sitp_tiradentes', 'sitp_cdg_este', 'sitp_defillo', 'sitp_cdg_oeste'}
# jsons: 100%|█████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.75it/s]
# jsons: 100%|█████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  8.03it/s]

# %%
# %run 52_walkmodel.ipynb
# Out:
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 27.43it/s]
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:07<00:00,  3.83it/s]
# zones: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 98.43it/s]
# Reprojecting model from epsg 4326 to epsg 32619: 100%|█████████████████████████████████| 33/33 [00:01<00:00, 24.40it/s]
# jsons: 100%|███████████████████████████████████████████████████████████████████████████| 27/27 [00:07<00:00,  3.41it/s]
# Reprojecting model from epsg 32619 to epsg 4326: 100%|█████████████████████████████████| 34/34 [00:17<00:00,  1.98it/s]
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 34/34 [01:11<00:00,  2.09s/it]
# could not save geometry from table fare_rules
# could not save geometry from table fare_attributes
# could not save geometry from table mode_nests
# could not save geometry from table logit_scales
# could not save geometry from table utility_values
