# %%
import pandas as pd
import sys
sys.path.insert(0, r'../../../quetzal')

from quetzal.io import  gtfs_importer
from quetzal.model import stepmodel, model

# %%
training_folder = '../../'

# %%
base = stepmodel.read_zip(training_folder + 'model/preparation/gtfs.zip')
base = base.change_epsg(epsg=32619, coordinates_unit='meter')
road = stepmodel.read_zip(training_folder + 'model/preparation/road.zip')

sm = base.copy()
sm.road_links = road.road_links
sm.road_nodes = road.road_nodes
# Out:
# read_hdf: : 100%|█████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 103.65it/s]
# Reprojecting model from epsg 4326 to epsg 32619: 100%|████████████████████████████████| 32/32 [00:00<00:00, 615.41it/s]
# read_hdf: : 100%|██████████████████████████████████████████████████████████████████████| 27/27 [00:01<00:00, 15.20it/s]

# %%
sm._add_type_prefixes()
# Out:
# can not add prefixes on table:  footpaths

# %% [markdown]
# # Networkcaster
# à faire sur un réseau propre, avant l'agrégation

# %%
sm.integrity_fix_sequences()
# Out:
# dropped broken sequences: []

# %%
sm.integrity_test_all(errors='raise', verbose=False)
# Out:
# 38589it [00:04, 8802.23it/s]
# 38589it [00:17, 2218.14it/s]

# %%
first_trips = set(sm.links.groupby(['route_id'])['trip_id'].min())
sm.links['direction_id'] = 0
sm.links.loc[sm.links['trip_id'].isin(first_trips), 'direction_id'] = 1
sm.links['trip_id'] = sm.links['route_id'] +'_' +(sm.links['direction_id'] + 1).astype(str)

# %% [markdown]
# ## rail

# %%
rail = sm.copy()
rail.links = rail.links.loc[rail.links['route_type'].isin(
    ['tram', 'subway', 'rail', 'brt', 'gondola', 'cable_car', 'express_bus']
)
]
rail.preparation_cast_network(dumb_cast=True)
# Out:
# nearest_link: 100%|████████████████████████████████████████████████████████████| 2810/2810 [00:00<00:00, 100349.89it/s]

# %% [markdown]
# ## road

# %%
road = sm.copy()
road.links = road.links.loc[road.links['route_type'].isin(['bus'])]

# %%
road.preparation_cast_network(
    nearest_method='nodes',
    n_neighbors_centroid=20, 
    n_neighbors=10, 
    penalty_factor=1,
    replace_nodes=False
)
# Out:
# nearest_link: 100%|████████████████████████████████████████████████████████████| 5620/5620 [00:00<00:00, 110201.49it/s]
# sitp_ortega_2100%|█████████████████████████████████████████████████████████████████████| 32/32 [00:24<00:00,  2.49it/s]

# %% [markdown]
# ## both road and rail

# %%
both = road.copy()
both.links = pd.concat([road.links, rail.links])

# %%
if not len(sm.links) == len(both.links):
    print('if not len(sm.links) == len(both.links): cuidado ')

# %%
both.analysis_lines(line_columns='all')

# %% [markdown]
# # to_zip

# %%
both.to_zip(
    training_folder + 'model/preparation/gtfs_networkcasted.zip',
    only_attributes=('links', 'nodes', 'epsg', 'coordinates_unit')
)
# Out:
# to_hdf(new file): 100%|███████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 234.57it/s]

# %%
# %matplotlib inline
both.plot('links', ax=both.plot('road_links', color='green', figsize=[16, 9], linewidth=0.1))
both.plot('lines', figsize=[16, 9], column='route_color')

# %% [markdown]
# # networkcaster_monitoring

# %%
from shapely.geometry import LineString

links = road.links
links['link_straight_length'] = links['geometry'].apply(
    lambda g: LineString([list(g.coords[0]), list(g.coords[-1])]).length
)

road.build_lines(sum_columns=['link_straight_length'])
lines = road.lines
lines['length'] = lines['geometry'].apply(lambda g: g.length)
lines['straight_length'] = lines['geometry'].apply(
    lambda g: LineString([list(g.coords[0]), list(g.coords[-1])]).length
)

lines['length_ratio'] = lines['length']/lines['link_straight_length']

# summary
(lines[['link_straight_length', 'straight_length', 'length']].sum() / 1000).astype(int)
# Out:
# Deprecated: replaced by analysis_lines
# link_straight_length    203
# straight_length         174
# length                  214
# dtype: int32

# %%
# %matplotlib inline
ax = lines['length_ratio'].hist(bins=100)

# %%
lines.sort_values('length_ratio').tail()
# Out:
#              trip_id        route_id  direction_id              trip_headsign  \
# 18      sitp_nunez_1      sitp_nunez             0  first trip of the pattern
# 13    sitp_defillo_2    sitp_defillo             1  first trip of the pattern
# 10  sitp_churchill_1  sitp_churchill             0  first trip of the pattern
# 19      sitp_nunez_2      sitp_nunez             1  first trip of the pattern
# 8   sitp_cdg_oeste_1  sitp_cdg_oeste             0  first trip of the pattern
#
#    trip_short_name block_id  shape_id service_id route_long_name  \
# 18         default  default     61572     Martes      sitp_nunez
# 13         default  default     58286     Martes    sitp_defillo
# 10         default  default     61570     Martes  sitp_churchill
# 19         default  default     61573     Martes      sitp_nunez
# 8          default  default     61578     Martes  sitp_cdg_oeste
#
#    route_short_name route_type route_color  link_straight_length  \
# 18       sitp_nunez        bus      C00098          10361.673240
# 13     sitp_defillo        bus      FB106E           2805.841027
# 10   sitp_churchill        bus      C179BF           8204.271050
# 19       sitp_nunez        bus      C00098          10174.881561
# 8    sitp_cdg_oeste        bus      749219          15328.070962
#
#                                              geometry        length  \
# 18  LINESTRING (398799.2236725556 2045831.30586844...  11386.098918
# 13  LINESTRING (399921.6136939948 2041106.97032433...   3148.905434
# 10  LINESTRING (402062.9422737417 2040350.50697394...   9232.827820
# 19  LINESTRING (402062.9422737417 2040350.50697394...  11563.831469
# 8   LINESTRING (404973.6243496398 2050791.77310086...  18497.667192
#
#     straight_length  length_ratio
# 18      6378.950982      1.098867
# 13      2725.300649      1.122268
# 10      6353.034864      1.125368
# 19      6373.506408      1.136508
# 8      11589.747483      1.206784
