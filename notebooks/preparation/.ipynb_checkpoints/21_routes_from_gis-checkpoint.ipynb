# %%
import sys
sys.path.insert(0, r'../../../quetzal')

from quetzal.io import  importer
from quetzal.model import stepmodel

import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
training_folder = '../../'
input_folder = training_folder + r'/inputs/'

# %% [markdown]
# # rail

# %%
lines = gpd.read_file(input_folder+'lines.geojson').set_index('route_name')
#lines['geometry'] = lines['geometry'].apply(lambda g: g[0])

# %%
lines.plot()

# %%
links, nodes = importer.from_lines(lines, add_return=False)

# %%
links = pd.merge(links, lines[['route_type']], left_on='trip_id', right_index=True)

# %%
links.head()
# Out:
#    a  b  link_sequence  direction_id  \
# 0  0  1              0             0
# 1  1  2              1             0
# 2  2  3              2             0
# 3  3  4              3             0
# 4  4  5              4             0
#
#                                             geometry    line trip_id route_id  \
# 0  LINESTRING (-69.901411 18.549246, -69.90093299...  LM01_1  LM01_1   LM01_1
# 1  LINESTRING (-69.90093299999999 18.546629, -69....  LM01_1  LM01_1   LM01_1
# 2  LINESTRING (-69.90447399999999 18.540005, -69....  LM01_1  LM01_1   LM01_1
# 3  LINESTRING (-69.908511 18.529458, -69.916248 1...  LM01_1  LM01_1   LM01_1
# 4  LINESTRING (-69.916248 18.525359, -69.91505600...  LM01_1  LM01_1   LM01_1
#
#    route_type
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
#links['route_type'] = 1
links['route_color'] = "#D22328" # rouge systra
sm = stepmodel.StepModel(epsg=4326, coordinates_unit='degree')
sm.links, sm.nodes = links, nodes

# %%
sm.plot(
    'links', linewidth=0.2, 
    ax=sm.plot('nodes', color='green', markersize=1, figsize=[16, 9])
)

# %%
sm.integrity_fix_collision()
# Out:
# can not add prefixes on table:  footpaths

# %%
sm.links['route_type'].value_counts()
# Out:
# 32    7583
# 33    4937
# 31    1031
# 1       62
# Name: route_type, dtype: int64

# %%
route_type_dict = {
        0:'tram',
        1:'subway',
        2:'rail',
        3:'bus',
        4:'ferry',
        5:'cable_car',
        6:'gondola',
        7:'funicular',
        31: 'bus',
        32: 'minibus',
        33: 'concho',
    }
sm.links['route_type'] = sm.links['route_type'].apply(lambda i: route_type_dict[i])

# %%
projected = sm.change_epsg(epsg=32619, coordinates_unit='meter')
projected.to_zip(training_folder + r'model/preparation/lines.zip')
# Out:
# Reprojecting model from epsg 4326 to epsg 32619: 100%|█████████████████████████████████| 26/26 [00:00<00:00, 29.48it/s]
# to_hdf(new file): 100%|████████████████████████████████████████████████████████████████| 26/26 [00:01<00:00, 11.29it/s]
