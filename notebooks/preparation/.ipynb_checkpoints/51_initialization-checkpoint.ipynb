# %% [markdown]
# # import

# %%
import sys
sys.path.insert(0, r'../../../quetzal')

from quetzal.model import stepmodel

import geopandas as gpd
from shapely import geometry
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
training_folder = '../../'
input_folder = training_folder + r'inputs/'

# %% [markdown]
# # read_file

# %%
links = gpd.read_file(input_folder+'gtfs/links.geojson', driver='GeoJSON')
nodes = gpd.read_file(input_folder+'gtfs/nodes.geojson', driver='GeoJSON')
zones = gpd.read_file(input_folder+'zones/zones.geojson', driver='GeoJSON')

# %%
zones.index = zones['index']

# %% [markdown]
# # set_index with node IDs

# %%
nodes
# Out:
#        index                              geometry
# 0    1000123          POINT (-69.869702 18.491544)
# 1    1000107          POINT (-69.951167 18.467167)
# 2    1000272          POINT (-69.861408 18.497362)
# 3    1000278           POINT (-69.95661 18.462808)
# 4    1000273          POINT (-69.992073 18.479736)
# 5    1000279          POINT (-70.021804 18.521059)
# 6    1000233  POINT (-69.92906000000001 18.482591)
# 7    1000232          POINT (-69.927798 18.478373)
# 8    1000231  POINT (-69.92681899999999 18.475425)
# 9    1000230           POINT (-69.925573 18.47256)
# 10   1000280            POINT (-69.92359 18.46903)
# 11   1000229          POINT (-69.920424 18.476214)
# 12   1000266          POINT (-69.994376 18.472014)
# 13   1000260  POINT (-69.99908000000001 18.500148)
# 14   1000254          POINT (-69.999172 18.503027)
# 15   1000228          POINT (-69.999179 18.497939)
# 16   1000227          POINT (-69.999593 18.489777)
# 17   1000226          POINT (-69.998395 18.484582)
# 18   1000225          POINT (-69.997484 18.478243)
# 19   1000261  POINT (-69.99425599999999 18.472266)
# 20   1000224          POINT (-69.994595 18.465638)
# 21   1000223          POINT (-69.991238 18.460624)
# 22   1000222          POINT (-69.984022 18.458019)
# 23   1000221  POINT (-69.91377900000001 18.546083)
# 24   1000220          POINT (-69.907038 18.547267)
# 25   1000219          POINT (-69.996303 18.507884)
# 26   1000218  POINT (-69.98456400000001 18.506653)
# 27   1000217          POINT (-69.975819 18.506874)
# 28   1000216  POINT (-69.96642300000001 18.509202)
# 29   1000215          POINT (-69.951303 18.547944)
# ..       ...                                   ...
# 225  1000042          POINT (-69.977267 18.486117)
# 226  1000033          POINT (-69.860692 18.543121)
# 227  1000016          POINT (-69.865599 18.530886)
# 228  1000015          POINT (-69.881829 18.517249)
# 229  1000032  POINT (-69.92086399999999 18.482265)
# 230  1000031          POINT (-69.931128 18.482702)
# 231  1000030          POINT (-69.940636 18.484085)
# 232  1000029  POINT (-69.94614799999999 18.482369)
# 233  1000028  POINT (-69.95478199999999 18.481799)
# 234  1000026  POINT (-69.96241999999999 18.480015)
# 235  1000014          POINT (-69.884084 18.503824)
# 236  1000013           POINT (-69.889878 18.49974)
# 237  1000025  POINT (-69.89568800000001 18.495786)
# 238  1000024  POINT (-69.89951600000001 18.493104)
# 239  1000012          POINT (-69.904385 18.487426)
# 240  1000023            POINT (-69.9064 18.481557)
# 241  1000021  POINT (-69.90451400000001 18.539752)
# 242  1000011  POINT (-69.90836299999999 18.529528)
# 243  1000010          POINT (-69.916451 18.525107)
# 244  1000009          POINT (-69.914879 18.518186)
# 245  1000008            POINT (-69.91551 18.50783)
# 246  1000007          POINT (-69.915406 18.499803)
# 247  1000006  POINT (-69.91499399999999 18.493725)
# 248  1000005  POINT (-69.91445400000001 18.486123)
# 249  1000004           POINT (-69.91417 18.481859)
# 250  1000003          POINT (-69.912048 18.471028)
# 251  1000002  POINT (-69.90980999999999 18.464401)
# 252  1000001          POINT (-69.916257 18.459258)
# 253  1000000          POINT (-69.924471 18.455344)
# 254  1000019          POINT (-69.927493 18.451097)
#
# [255 rows x 2 columns]

# %%
nodes.set_index('stop_id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'stop_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1c3ab6dfa430> in <module>()
# ----> 1 nodes.set_index('stop_id', inplace=True)
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2926                 names.append(None)
#    2927             else:
# -> 2928                 level = frame[col]._values
#    2929                 names.append(col)
#    2930                 if drop:
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     396         GeoDataFrame.
#     397         """
# --> 398         result = super(GeoDataFrame, self).__getitem__(key)
#     399         geo_col = self._geometry_column_name
#     400         if isinstance(key, string_types) and key == geo_col:
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'stop_id'

# %% [markdown]
# # cut with convex hull

# %%
road_nodes = gpd.read_file(input_folder+'road/road_nodes.geojson', driver='GeoJSON')
convex_hull = geometry.MultiPolygon(list(zones['geometry'])).convex_hull.buffer(0.002)
convex_hull

# %%
ax = zones.plot()

# %%
def cut(gdf, stencil):
    contained = gdf['geometry'].apply(lambda g: stencil.contains(g))
    return gdf.loc[contained]

plt.rcParams['figure.figsize'] = [10, 7]

# %% [markdown]
# # initialize_model

# %%
sm = stepmodel.StepModel()
# Out:
# Model epsg not defined: setting epsg to default one: 4326
# Model coordinates_unit not defined: setting coordinates_unit to default one: degree

# %%
sm.links = cut(links, convex_hull)
sm.nodes = cut(nodes, convex_hull)
sm.zones = cut(zones, convex_hull)

# %%
ax = sm.plot('zones', alpha=0.5, figsize=[17, 7])
ax = sm.plot('links', linewidth=0.5, color='green', ax=ax)
plot= sm.plot('nodes', markersize=0.5, color='red', ax=ax)

# %%
sm.to_zip(training_folder + r'model/preparation/base.zip')
# Out:
# to_hdf(new file): 100%|████████████████████████████████████████████████████████████████| 26/26 [00:01<00:00, 17.64it/s]

# %% [markdown]
# # json

# %%
sm.to_json(training_folder + r'model/latest')
# Out:
# to_hdf(overwriting): 100%|█████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 21.29it/s]
