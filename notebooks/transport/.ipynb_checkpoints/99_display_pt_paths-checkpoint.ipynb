# %%
import geopandas as gpd
import pandas as pd

work_path = r'../../../'
quetzal_path = work_path + r'quetzal_santo_domingo/model/'

import sys
sys.path.insert(0, '../../../quetzal/')

from quetzal.model import stepmodel
from quetzal.io import display

# %%
sm = stepmodel.read_zip(quetzal_path + r'base/pt_pathfinder.zip')
# Out:
# read_hdf: : 100%|██████████████████████████████████████████████████████████████████████| 26/26 [00:02<00:00,  7.69it/s]

# %%
# %matplotlib inline
sm.pt_los.set_index(['origin', 'destination']).loc[('zone_20',  'zone_89')]['gtime'].hist(bins=25)

# %%
sm.pt_los.set_index(['origin', 'destination']).loc[('zone_1',  'zone_105')]
# Out:
#                    alighting_links  alightings  all_walk boarding_links  \
# origin destination
# zone_1 zone_105         [link_632]  [node_843]     False     [link_623]
#        zone_105                 []          []      True             []
#        zone_105        [link_8685]  [node_591]     False    [link_8681]
#        zone_105        [link_3235]  [node_591]     False    [link_3231]
#        zone_105         [link_775]  [node_647]     False     [link_766]
#
#                      boardings              broken_modes broken_route  \
# origin destination
# zone_1 zone_105     [node_284]                       NaN          NaN
#        zone_105             []  {minibus, concho, heavy}          NaN
#        zone_105     [node_284]           {concho, heavy}          NaN
#        zone_105     [node_284]          {minibus, heavy}          NaN
#        zone_105     [node_284]                       NaN     AB_A11_2
#
# ...

# %%
projected = sm.change_epsg(epsg=4326, coordinates_unit='degree')
# Out:
# Reprojecting model from epsg 32619 to epsg 4326: 100%|█████████████████████████████████| 33/33 [00:01<00:00, 32.71it/s]

# %%
display.all_pt_paths(projected, 'zone_1',  'zone_105', color_column='route_color')
# Out:
# 5 paths
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.86it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sm.pt_los.set_index(['origin', 'destination']).loc['zone_117']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [zone_117] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-574e59355a29> in <module>()
# ...

# %%
display.all_pt_paths(sm, 'zone_117',  'zone_83', color_column='line_color')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# C:\Users\qchasserieau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [zone_117] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-df3c2ed81f2c> in <module>()
# ...

# %%
display.all_pt_paths(sm, 'zone_15',  'zone_77',color_column='line_color')
# Out:
# 10 paths
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:02<00:00,  4.15it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
